# %%
from deepface import DeepFace
import cv2

# %%
img1_path = "dataset/img1.jpg"

# %%
img1 = cv2.imread(img1_path)

# %%
alpha = DeepFace.extract_faces(img1)[0]["face"]
beta = DeepFace.extract_faces(img1_path)[0]["face"]

# %%
alpha
# Out:
# array([[[0.67843137, 0.69411765, 0.69019608],
#         [0.67843137, 0.69411765, 0.69019608],
#         [0.68627451, 0.70196078, 0.69803922],
#         ...,
#         [0.69411765, 0.69803922, 0.69411765],
#         [0.71764706, 0.72156863, 0.72156863],
#         [0.71372549, 0.71764706, 0.71372549]],
#
#        [[0.69019608, 0.70980392, 0.70588235],
#         [0.69019608, 0.70980392, 0.70588235],
#         [0.69019608, 0.70980392, 0.70588235],
#         ...,
#         [0.70196078, 0.70980392, 0.70588235],
#         [0.71372549, 0.71764706, 0.71764706],
#         [0.70980392, 0.71764706, 0.71372549]],
#
#        [[0.69411765, 0.71764706, 0.70980392],
#         [0.68627451, 0.71372549, 0.70196078],
#         [0.69019608, 0.71372549, 0.70588235],
#         ...,
#         [0.71372549, 0.72156863, 0.71764706],
#         [0.70980392, 0.71764706, 0.71372549],
#         [0.70196078, 0.70980392, 0.70588235]],
#
#        ...,
#
#        [[0.11372549, 0.12941176, 0.17647059],
# ...

# %%
beta
# Out:
# array([[[0.67843137, 0.69411765, 0.69019608],
#         [0.67843137, 0.69411765, 0.69019608],
#         [0.68627451, 0.70196078, 0.69803922],
#         ...,
#         [0.69411765, 0.69803922, 0.69411765],
#         [0.71764706, 0.72156863, 0.72156863],
#         [0.71372549, 0.71764706, 0.71372549]],
#
#        [[0.69019608, 0.70980392, 0.70588235],
#         [0.69019608, 0.70980392, 0.70588235],
#         [0.69019608, 0.70980392, 0.70588235],
#         ...,
#         [0.70196078, 0.70980392, 0.70588235],
#         [0.71372549, 0.71764706, 0.71764706],
#         [0.70980392, 0.71764706, 0.71372549]],
#
#        [[0.69411765, 0.71764706, 0.70980392],
#         [0.68627451, 0.71372549, 0.70196078],
#         [0.69019608, 0.71372549, 0.70588235],
#         ...,
#         [0.71372549, 0.72156863, 0.71764706],
#         [0.70980392, 0.71764706, 0.71372549],
#         [0.70196078, 0.70980392, 0.70588235]],
#
#        ...,
#
#        [[0.11372549, 0.12941176, 0.17647059],
# ...
