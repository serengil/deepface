# %%
# built-in dependencies
import os

# 3rd party dependencies
import psycopg
from deepface import DeepFace
from tqdm import tqdm

# %% [markdown]
# ### Database Connection

# %%
connection_details={
    "host": "localhost",
    "port": 5433,
    "dbname": "deepface",
    "user": "deepface_user",
    "password": "deepface_pass",
}

# %%
conn = psycopg.connect(**connection_details)

# %% [markdown]
# ## Search

# %%
dfs = DeepFace.search(
    img="../integration/dataset/target.jpg",
    model_name="Facenet",
    detector_backend="mtcnn",
    connection=conn,
)

# %%
len(dfs)
# Out:
# 1

# %%
dfs[0].shape
# Out:
# (8, 7)

# %%
dfs[0]
# Out:
#      id                        img_name model_name detector_backend  aligned  \
# 54  162                dataset/img7.jpg    Facenet            mtcnn     True
# 31  139  dataset/selfie-many-people.jpg    Facenet            mtcnn     True
# 59  167                dataset/img2.jpg    Facenet            mtcnn     True
# 49  157                dataset/img5.jpg    Facenet            mtcnn     True
# 53  161                dataset/img6.jpg    Facenet            mtcnn     True
# 0   106        ../unit/dataset/img1.jpg    Facenet            mtcnn     True
# 29  137    dataset/img11_reflection.jpg    Facenet            mtcnn     True
# 50  158                dataset/img4.jpg    Facenet            mtcnn     True
#
#     l2_normalized  distance
# 54          False  0.157526
# 31          False  0.199807
# 59          False  0.203507
# 49          False  0.207596
# 53          False  0.211547
# 0           False  0.236827
# 29          False  0.244111
# 50          False  0.248995

# %% [markdown]
# ### Collect items

# %%
database_items = []
for dirpath, dirnames, filenames in os.walk("dataset"):
    for filename in filenames:
        if not filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue
        filepath = os.path.join(dirpath, filename)
        database_items.append(filepath)

# %%
len(database_items)

# %%
for img_path in tqdm(database_items):
    _ = DeepFace.register(
        img=img_path,
        model_name="Facenet",
        detector_backend="mtcnn",
        connection=conn,
    )

# %% [markdown]
# ### Search
