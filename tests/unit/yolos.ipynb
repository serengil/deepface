# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

# %%
img_path = "dataset/img11.jpg"

# %%
detectors = [
    "ssd",
    "yolov8n",
    "yolov8m",
    "yolov8l",
    "yolov11n",
    "yolov11s",
    "yolov11m",
    "yolov11l",
    "yolov12n",
    "yolov12s",
    "yolov12m",
    "yolov12l",
]

# %%
for detector in detectors:
    print(f"Detector: {detector}")
    img = cv2.imread(img_path)

    results = DeepFace.extract_faces(
        img_path=img_path,
        detector_backend=detector
    )

    fig = plt.figure(figsize=(10, 7))
    for result in results:
        facial_area = result["facial_area"]

        x = facial_area["x"]
        y = facial_area["y"]
        w = facial_area["w"]
        h = facial_area["h"]
        left_eye = facial_area["left_eye"]
        right_eye = facial_area["right_eye"]

        print(left_eye, right_eye)

        img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        img = cv2.circle(img, left_eye, 5, (0, 0, 255), -1)
        img = cv2.circle(img, right_eye, 5, (0, 0, 255), -1)

        plt.imshow(img[:,:,::-1])
        plt.show()

        plt.imshow(result["face"])
        plt.show()
    
    print("-----------")
# Out:
# Detector: ssd
# (372, 247) (249, 210)
# -----------
# Detector: yolov8n
# (373, 246) (251, 214)
# -----------
# Detector: yolov8m
# (372, 246) (247, 210)
# -----------
# Detector: yolov8l
# (372, 246) (249, 211)
# -----------
# Detector: yolov11n
# (372, 246) (248, 211)
# -----------
# Detector: yolov11s
# (371, 246) (248, 211)
# -----------
# Detector: yolov11m
# (372, 247) (248, 211)
# -----------
# Detector: yolov11l
# (372, 246) (249, 210)
# -----------
# Detector: yolov12n
# (372, 247) (248, 210)
# -----------
# Detector: yolov12s
# (371, 246) (248, 210)
# -----------
# Detector: yolov12m
# (372, 246) (248, 211)
# -----------
# Detector: yolov12l
# (372, 246) (248, 211)
# -----------
